# %%
from PIL import Image as IMG
import numpy as np
from pprint import pprint
import pandas as pd
from runs import NORM
import numpy as np
import os
sep = os.sep
import matplotlib.pyplot as plt
import runs

# %%
arr = np.array(IMG.open('data' + sep + NORM['labels_dir']+sep+'1.png'))

# %%
IMG.fromarray(arr)
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480 at 0x7F66F53CF880>

# %%
arr.shape
# Out:
# (480, 640, 4)

# %%
arr = np.rollaxis(arr, 2, 0)
arr.shape
# Out:
# (4, 480, 640)

# %%
np.rollaxis(arr, 0, 3).shape
# Out:
# (480, 640, 4)

# %%
rgb = []
for i in range(arr.shape[0]):
    for j in range(arr.shape[1]):
        rgb.append(arr[i, j, :])

# %%
img_classes = [tuple(a.tolist()[:-1]) for a in np.unique(np.array(rgb), axis=0)]

# %%
np.unique(np.array(rgb), axis=0)
# Out:
# array([[  0,   0,   0, 255],
#        [  0,   0,  51, 255],
#        [  0,  25,   0, 255],
#        [  0, 255,   0, 255],
#        [  0, 255, 255, 255],
#        [ 38,  51,  76, 255],
#        [ 89,  20,   0, 255],
#        [101, 101, 101, 255],
#        [101, 178,   0, 255],
#        [255,   0,   0, 255],
#        [255,   0, 255, 255],
#        [255, 255,   0, 255]], dtype=uint8)

# %%
255*.4
# Out:
# 102.0

# %%
IMG.fromarray(arr)
# Out:
# <PIL.Image.Image image mode=RGBA size=640x480 at 0x11CF64A7970>

# %%
r, g, b = R.CLASS_RGB['Couch']
logic = np.logical_and.reduce([arr[:,:,0]==r, arr[:,:,1]==g, arr[:,:,2]==b])
ix = np.array(list(zip(*np.where(logic))))

# %%
i = np.zeros_like(arr[:,:,0])
i[ix[:,0], ix[:,1]] = 255

# %%
IMG.fromarray(i)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x11CF64A7CA0>

# %%
arr.shape
# Out:
# (480, 640, 4)

# %%
import math

# %%
arr.shape
# Out:
# (480, 640, 4)

# %%
import json

# %%
json.load(open('SEG.json'))
# Out:
# {'train': ['1.png', '2.png', '3.png'],
#  'validation': ['4.png', '5.png'],
#  'test': ['6.png', '7.png']}

# %%
json = {
  "train": [
    "1.png",
    "2.png",
    "3.png"
    ],
  "validation": [
   "4.png",
   "5.png"
  ],
  "test": [
    "6.png",
    "7.png"
  ]
}

# %%
json
# Out:
# {'train': ['1.png', '2.png', '3.png'],
#  'validation': ['4.png', '5.png'],
#  'test': ['6.png', '7.png']}
